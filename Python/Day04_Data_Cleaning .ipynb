# %% [markdown]
# # Day 04 - Data Cleaning
#
# ## Objective
# Check data quality before starting the analysis.

# %%
import pandas as pd

df = pd.read_excel("C:/Data Projects/Ecommerce_Sales_Analysis/Data/Superstore.xlsx")

# %% [markdown]
# ### Missing Values
#
# - No missing values were found in the dataset.

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### Duplicate Rows
#
# - No duplicate rows were detected.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Types
#
# - All columns have appropriate data types.
# - Date columns (`Order Date` and `Ship Date`) are correctly stored as **datetime**.

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# ### Negative Profit
#
# - 1,871 rows contain negative profit.
# - These records were **not removed** because they represent real business losses rather than data errors.

# %%
negative_profit = df[df["Profit"] < 0]

negative_profit
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 1866    1867  CA-2017-118857 2017-04-15 2017-04-18     First Class
# 1867    1868  CA-2015-127110 2015-06-25 2015-07-01  Standard Class
# 1868    1869  CA-2015-127110 2015-06-25 2015-07-01  Standard Class
# 1869    1870  CA-2016-148201 2016-08-26 2016-08-29    Second Class
# 1870    1871  CA-2014-116932 2014-07-21 2014-07-25  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# ...

# %%
(df["Profit"] < 0).sum()
# Out:
# 1871

# %%
df["Profit"].min()
# Out:
# -6599.978

# %%
negative_profit[
    ["Order ID", "Product Name", "Sales", "Discount", "Profit"]
]
# Out:
#             Order ID                                       Product Name  \
# 0     CA-2016-152156                  Bush Somerset Collection Bookcase
# 1     CA-2016-152156  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2     CA-2016-138688  Self-Adhesive Address Labels for Typewriters b...
# 3     US-2015-108966      Bretford CR4500 Series Slim Rectangular Table
# 4     US-2015-108966                     Eldon Fold 'N Roll Cart System
# ...              ...                                                ...
# 1866  CA-2017-118857                 Howard Miller 12" Round Wall Clock
# 1867  CA-2015-127110                                          Xerox 211
# 1868  CA-2015-127110                        Tennsco Industrial Shelving
# 1869  CA-2016-148201                                         Xerox 1931
# 1870  CA-2014-116932                                         Newell 334
#
#        Sales  Discount     Profit
# 0      0.444      0.00 -6599.9780
# ...

# %%
negative_profit = df[df["Profit"] < 0]

negative_profit.shape
# Out:
# (1871, 21)

# %%
df[["Sales", "Profit"]].describe()
# Out:
#               Sales       Profit
# count   9994.000000  9994.000000
# mean     229.858001    28.656896
# std      623.245101   234.260108
# min        0.444000 -6599.978000
# 25%       17.280000     1.728750
# 50%       54.490000     8.666500
# 75%      209.940000    29.364000
# max    22638.480000  8399.976000

# %% [markdown]
# ### Duplicate Order IDs
#
# - Duplicate Order IDs are expected because a single order can contain multiple products.
# - Therefore, they are not considered duplicates in terms of data quality.

# %%
df["Order ID"].duplicated().sum()

# %% [markdown]
# ## Data Quality Checks
#
# ## Key Findings
#
# - The dataset is clean and contains no missing values.
# - No duplicate rows exist.
# - Data types are correctly assigned.
# - Negative profits are valid business records.
# - The dataset is ready for exploratory data analysis (EDA).
#
# ---
#
# ## Skills Learned
#
# - Detecting missing values using `isnull()`.
# - Identifying duplicate rows using `duplicated()`.
# - Reviewing data types using `dtypes`.
# - Summarizing numerical data using `describe()`.
# - Distinguishing between data errors and valid business scenarios.
# - Performing a basic data quality assessment before analysis.
#
# ---
#
# ## Conclusion
#
# The dataset passed all major data quality checks and does not require additional cleaning. It is ready for exploratory data analysis in the next stage.
