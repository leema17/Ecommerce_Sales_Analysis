# %% [markdown]
# ## Day 06 – Business Analysis with Pandas
#
# ## Objective
# Analyze business performance by answering real business questions using Pandas

# %%
import pandas as pd

df = pd.read_excel("C:/Data Projects/Ecommerce_Sales_Analysis/Data/Superstore.xlsx")

# %% [markdown]
# ## Sales by Category

# %%
sales_by_category = (
    df.groupby("Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

sales_by_category
# Out:
# Category
# Office Supplies    1.374844e+06
# Furniture          4.826520e+05
# Technology         4.397044e+05
# Name: Sales, dtype: float64

# %% [markdown]
# ## Profit by Category

# %%
profit_by_category = (
    df.groupby("Category")["Profit"]
    .sum()
    .sort_values(ascending=False)
)

profit_by_category
# Out:
# Category
# Office Supplies    175444.8860
# Technology          61606.0643
# Furniture           49346.0714
# Name: Profit, dtype: float64

# %% [markdown]
# ## Sales by Sub-Category

# %%
sales_by_subcategory = (
    df.groupby("Sub-Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

sales_by_subcategory
# Out:
# Sub-Category
# Binders        344743.2525
# Paper          330122.5722
# Furnishings    234348.8618
# Phones         209109.1062
# Accessories    198970.3208
# Storage        168392.3309
# Art            164084.6368
# Chairs         127971.7890
# Appliances     126183.6755
# Labels          89085.0995
# Tables          71093.5028
# Supplies        56196.8502
# Envelopes       55305.6193
# Bookcases       49237.8600
# Fasteners       40730.3758
# Machines        17439.3210
# Copiers         14185.6860
# Name: Sales, dtype: float64

# %% [markdown]
# ## Sales by Region

# %%
sales_by_region = (
    df.groupby("Region")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

sales_by_region
# Out:
# Region
# West       759665.5578
# East       666387.9353
# Central    533287.9218
# South      337859.4454
# Name: Sales, dtype: float64

# %% [markdown]
# ## Sales by Customer Segment

# %%
sales_by_segment = (
    df.groupby("Segment")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

sales_by_segment
# Out:
# Segment
# Consumer       1.181091e+06
# Corporate      7.079800e+05
# Home Office    4.081303e+05
# Name: Sales, dtype: float64

# %% [markdown]
# ## Key Findings
#
# ### Sales by Category
#
# - Office Supplies generated the highest sales.
# - Furniture ranked second.
# - Technology ranked third.
#
# ### Profit by Category
#
# - Office Supplies achieved the highest profit.
# - Technology generated more profit than Furniture despite lower sales.
#
# ### Top Sub-Categories
#
# - Binders
# - Paper
# - Furnishings
# - Phones
# - Accessories
#
# ### Sales by Region
#
# - West recorded the highest sales.
# - South had the lowest sales performance.
#
# ### Sales by Customer Segment
#
# - Consumer is the largest customer segment.
# - Corporate ranked second.
# - Home Office generated the lowest sales.
#
# ---
#
# ## Skills Learned
#
# - Using `groupby()` for business analysis.
# - Aggregating data with `sum()`.
# - Sorting results using `sort_values()`.
# - Extracting business insights from aggregated data.
# - Comparing business performance across different dimensions.
#
# ---
#
# ## Conclusion
#
# The analysis shows that Office Supplies is the strongest-performing category in both sales and profit. The West region contributes the highest sales, while the Consumer segment generates the largest share of revenue. These findings provide valuable insights for future business decisions and marketing strategies.
